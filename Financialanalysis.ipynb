# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('Financial Analytics data.csv')

# %%
df.head()
# Out:
#    S.No.            Name  Mar Cap - Crore  Sales Qtr - Crore  Unnamed: 4
# 0      1  Reliance Inds.        583436.72           99810.00         NaN
# 1      2             TCS        563709.84           30904.00         NaN
# 2      3       HDFC Bank        482953.59           20581.27         NaN
# 3      4             ITC        320985.27            9772.02         NaN
# 4      5         H D F C        289497.37           16840.51         NaN

# %%
df.tail()
# Out:
#      S.No.             Name  Mar Cap - Crore  Sales Qtr - Crore  Unnamed: 4
# 483    496  Lak. Vilas Bank          3029.57             790.17         NaN
# 484    497            NOCIL          3026.26             249.27         NaN
# 485    498    Orient Cement          3024.32             511.53         NaN
# 486    499  Natl.Fertilizer          3017.07            2840.75         NaN
# 487    500        L T Foods              NaN                NaN         NaN

# %%
df.shape
# Out:
# (488, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 488 entries, 0 to 487
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   S.No.              488 non-null    int64
#  1   Name               488 non-null    object
#  2   Mar Cap - Crore    479 non-null    float64
#  3   Sales Qtr - Crore  365 non-null    float64
#  4   Unnamed: 4         94 non-null     float64
# dtypes: float64(3), int64(1), object(1)
# memory usage: 19.2+ KB

# %%
df.isnull().sum()
# Out:
# S.No.                  0
# Name                   0
# Mar Cap - Crore        9
# Sales Qtr - Crore    123
# Unnamed: 4           394
# dtype: int64

# %%
print(df.columns)
# Out:
# Index(['S.No.', 'Name', 'Mar Cap - Crore', 'Sales Qtr - Crore', 'Unnamed: 4'], dtype='object')

# %%
df=df.drop(columns='Unnamed: 4',axis=1)

# %%
df.head()
# Out:
#    S.No.            Name  Mar Cap - Crore  Sales Qtr - Crore
# 0      1  Reliance Inds.        583436.72           99810.00
# 1      2             TCS        563709.84           30904.00
# 2      3       HDFC Bank        482953.59           20581.27
# 3      4             ITC        320985.27            9772.02
# 4      5         H D F C        289497.37           16840.51

# %%
df['Name'].unique()
# Out:
# array(['Reliance Inds.', 'TCS', 'HDFC Bank', 'ITC', 'H D F C',
#        'Hind. Unilever', 'Maruti Suzuki', 'Infosys', 'O N G C',
#        'St Bk of India', 'ICICI Bank', 'Kotak Mah. Bank', 'Coal India',
#        'Larsen & Toubro', 'I O C L', 'Bharti Airtel', 'Axis Bank', 'NTPC',
#        'Sun Pharma.Inds.', 'Hind.Zinc', 'Wipro', 'HCL Technologies',
#        'Vedanta', 'Tata Motors', 'UltraTech Cem.', 'Asian Paints',
#        'Power Grid Corpn', 'B P C L', 'IndusInd Bank', 'Bajaj Fin.',
#        'Bajaj Auto', 'M & M', 'HDFC Stand. Life', 'Adani Ports',
#        'Bajaj Finserv', 'GAIL (India)', 'Avenue Super.', 'Titan Company',
#        'JSW Steel', 'Grasim Inds', 'Tata Steel', 'Eicher Motors',
#        'Nestle India', 'Godrej Consumer', 'Yes Bank', 'Hero Motocorp',
#        'Motherson Sumi', 'SBI Life Insuran', 'General Insuranc',
#        'Bharti Infra.', 'Dabur India', 'Bosch', 'Shree Cement',
#        'New India Assura', 'H P C L', 'ICICI Pru Life', 'Britannia Inds.',
# ...

# %%
df.describe()
# Out:
#             S.No.  Mar Cap - Crore  Sales Qtr - Crore
# count  488.000000       479.000000         365.000000
# mean   251.508197     28043.857119        4395.976849
# std    145.884078     59464.615831       11092.206185
# min      1.000000      3017.070000          47.240000
# 25%    122.750000      4843.575000         593.740000
# 50%    252.500000      9885.050000        1278.300000
# 75%    378.250000     23549.900000        2840.750000
# max    500.000000    583436.720000      110666.930000

# %%
df['Sales Qtr - Crore'] = df['Sales Qtr - Crore'].fillna(df['Sales Qtr - Crore'].mean())

# %%
df['Mar Cap - Crore'] = df['Mar Cap - Crore'].fillna(df['Mar Cap - Crore'].mean())

# %%
df.isna().sum()
# Out:
# S.No.                0
# Name                 0
# Mar Cap - Crore      0
# Sales Qtr - Crore    0
# dtype: int64

# %%
df1=(df.iloc[0:26])

# %%
df1
# Out:
#     S.No.              Name  Mar Cap - Crore  Sales Qtr - Crore
# 0       1    Reliance Inds.        583436.72           99810.00
# 1       2               TCS        563709.84           30904.00
# 2       3         HDFC Bank        482953.59           20581.27
# 3       4               ITC        320985.27            9772.02
# 4       5           H D F C        289497.37           16840.51
# 5       6    Hind. Unilever        288265.26            8590.00
# 6       7     Maruti Suzuki        263493.81           19283.20
# 7       8           Infosys        248320.35           17794.00
# 8       9           O N G C        239981.50           22995.88
# 9      10    St Bk of India        232763.33           57014.08
# 10     11        ICICI Bank        203802.35           13665.35
# 11     12   Kotak Mah. Bank        199253.77            6390.71
# 12     13        Coal India        192677.98           21643.28
# 13     14   Larsen & Toubro        180860.74           28747.45
# ...

# %%
df.head()
# Out:
#    S.No.            Name  Mar Cap - Crore  Sales Qtr - Crore
# 0      1  Reliance Inds.        583436.72           99810.00
# 1      2             TCS        563709.84           30904.00
# 2      3       HDFC Bank        482953.59           20581.27
# 3      4             ITC        320985.27            9772.02
# 4      5         H D F C        289497.37           16840.51

# %%
file_name='A.xlsx'

# %%
df1.to_excel(file_name)

# %%
df.describe()
# Out:
#             S.No.  Mar Cap - Crore  Sales Qtr - Crore
# count  488.000000       488.000000         488.000000
# mean   251.508197     28043.857119        4395.976849
# std    145.884078     58912.585788        9589.680655
# min      1.000000      3017.070000          47.240000
# 25%    122.750000      4879.612500         725.732500
# 50%    252.500000     10380.425000        2095.335000
# 75%    378.250000     25502.085000        4395.976849
# max    500.000000    583436.720000      110666.930000

# %%
sns.pairplot(df)

# %%
sns.heatmap(df.corr(),annot=True)
plt.show()

# %%
sns.histplot(data=df,x='Mar Cap - Crore',bins=10)
plt.show()

# %%
sns.histplot(data=df,x='Sales Qtr - Crore',bins=10)
plt.show()

# %%
plt.figure(figsize=(16,7))
sns.barplot(x=df['Name'], y=df['Sales Qtr - Crore'])
plt.show()

# %%
plt.figure(figsize=(16,7))
sns.barplot(x=df['Name'], y=df['Mar Cap - Crore'])
plt.show()

# %%
df['Mar Cap - Crore'].plot(legend = True, figsize = (10,5))
plt.show()

# %%
df['Sales Qtr - Crore'].plot(legend = True, figsize = (10,5))
plt.show()

# %%
sns.jointplot(data=df,x='Sales Qtr - Crore',y='Mar Cap - Crore',kind='scatter')
plt.show()
